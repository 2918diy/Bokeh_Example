# %%
from bokeh.plotting import figure
from bokeh.io import show, output_notebook

# %%
# Create a blank figure with labels
p = figure(plot_width = 600, plot_height = 600, title = 'Example Glyphs', x_axis_label = 'X', y_axis_label = 'Y')

# %%
# Example data
squares_x = [1, 3, 4, 5, 8]
squares_y = [8, 7, 3, 1, 10]
circles_x = [9, 12, 4, 3, 15]
circles_y = [8, 4, 11, 6, 10]

# %%
# Add squares glyph
p.square(squares_x,squares_y,size = 12, color = 'navy',alpha = 0.6)
# Add circle glyph
p.circle(circles_x, circles_y, size=12, color="red", alpha=0.5)
# Out:
# GlyphRenderer(id='144159d5-88df-4df0-bb6e-0c5db84e98bb', ...)

# %%
# Set to output the plot in the notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9b5b35b8-397a-4fbd-8227-eefd1029e462">Loading BokehJS ...</span>
#     </div>

# %%
# Show the plot
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="736d94f6-8623-47d5-b373-0398a9a2f151"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("736d94f6-8623-47d5-b373-0398a9a2f151");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("736d94f6-8623-47d5-b373-0398a9a2f151");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '736d94f6-8623-47d5-b373-0398a9a2f151' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"62d84647-5c7a-43b8-9e9f-3b383a4bc92e":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"8ba382ed-5c38-4024-843d-e6bd90e56503","subtype":"Figure","type":"Plot"},"ticker":{"id":"93c9847d-8edf-4210-904f-a8e87e9981b3","type":"BasicTicker"}},"id":"8184c43b-07b4-4006-9f34-5175769c5b39","type":"Grid"},{"attributes":{"overlay":{"id":"803c04d8-0bf4-42a7-be89-06491fd2f495","type":"BoxAnnotation"}},"id":"4a182e3f-70f5-45db-a324-98638d00fe93","type":"BoxZoomTool"},{"attributes":{},"id":"a5600019-1a6f-45f5-a912-48fad0f793e7","type":"HelpTool"},{"attributes":{},"id":"a9be5417-87f2-4706-be72-7475ed07e8dd","type":"LinearScale"},{"attributes":{},"id":"93c9847d-8edf-4210-904f-a8e87e9981b3","type":"BasicTicker"},{"attributes":{},"id":"fbd8827a-4286-4904-a3a6-7f54fd38f39b","type":"LinearScale"},{"attributes":{},"id":"6d6d9a62-4a61-4112-a3c9-4337050310d2","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"value":"navy"},"line_alpha":{"value":0.6},"line_color":{"value":"navy"},"size":{"units":"screen","value":12},"x":{"field":"x"},"y":{"field":"y"}},"id":"3a7eef06-3d2b-4951-8b99-1ed25fe5fcc5","type":"Square"},{"attributes":{"axis_label":"X","formatter":{"id":"49f5bf02-664f-411c-920c-afbf13e6093a","type":"BasicTickFormatter"},"plot":{"id":"8ba382ed-5c38-4024-843d-e6bd90e56503","subtype":"Figure","type":"Plot"},"ticker":{"id":"a7c9eae5-e8fa-4f19-93a7-668e6e704c20","type":"BasicTicker"}},"id":"c09ed6c7-94a8-45df-918e-96af05f925c4","type":"LinearAxis"},{"attributes":{},"id":"a7c9eae5-e8fa-4f19-93a7-668e6e704c20","type":"BasicTicker"},{"attributes":{"axis_label":"Y","formatter":{"id":"d2998e22-881a-4dc5-8701-d9a048969520","type":"BasicTickFormatter"},"plot":{"id":"8ba382ed-5c38-4024-843d-e6bd90e56503","subtype":"Figure","type":"Plot"},"ticker":{"id":"93c9847d-8edf-4210-904f-a8e87e9981b3","type":"BasicTicker"}},"id":"b787693b-fc66-45ca-afc8-d6e832c7491c","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"803c04d8-0bf4-42a7-be89-06491fd2f495","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":12},"x":{"field":"x"},"y":{"field":"y"}},"id":"ecaad2df-8f08-44b1-9a99-4ca0e323b7ce","type":"Square"},{"attributes":{"data_source":{"id":"ae94bfe0-690b-4f7e-85a1-ca6696883c25","type":"ColumnDataSource"},"glyph":{"id":"3a7eef06-3d2b-4951-8b99-1ed25fe5fcc5","type":"Square"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ecaad2df-8f08-44b1-9a99-4ca0e323b7ce","type":"Square"},"selection_glyph":null,"view":{"id":"8eaf1187-e7b5-4fea-bab2-ddf82dfb7c73","type":"CDSView"}},"id":"0ce32110-341e-413a-a7e2-7b1d0c3c2896","type":"GlyphRenderer"},{"attributes":{},"id":"0541499e-7399-4165-8e6d-c5586cd63636","type":"PanTool"},{"attributes":{"plot":{"id":"8ba382ed-5c38-4024-843d-e6bd90e56503","subtype":"Figure","type":"Plot"},"ticker":{"id":"a7c9eae5-e8fa-4f19-93a7-668e6e704c20","type":"BasicTicker"}},"id":"71558b84-9774-4658-b3b2-1e7ffd1489a0","type":"Grid"},{"attributes":{"below":[{"id":"c09ed6c7-94a8-45df-918e-96af05f925c4","type":"LinearAxis"}],"left":[{"id":"b787693b-fc66-45ca-afc8-d6e832c7491c","type":"LinearAxis"}],"renderers":[{"id":"c09ed6c7-94a8-45df-918e-96af05f925c4","type":"LinearAxis"},{"id":"71558b84-9774-4658-b3b2-1e7ffd1489a0","type":"Grid"},{"id":"b787693b-fc66-45ca-afc8-d6e832c7491c","type":"LinearAxis"},{"id":"8184c43b-07b4-4006-9f34-5175769c5b39","type":"Grid"},{"id":"803c04d8-0bf4-42a7-be89-06491fd2f495","type":"BoxAnnotation"},{"id":"0ce32110-341e-413a-a7e2-7b1d0c3c2896","type":"GlyphRenderer"},{"id":"144159d5-88df-4df0-bb6e-0c5db84e98bb","t ...
